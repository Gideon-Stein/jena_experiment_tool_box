# %%
import pickle
from os import listdir
from os.path import isdir, isfile, join
import sys
sys.path.append("..")
from tools import *

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plot the datetime progressing throughout the year

# %%
# All paths
tables,tables_list = get_all_paths()
mypath = "/home/datasets4/stein/supplements_jena_experiment/Y2021001bis365_csv"
supplements = [mypath + "/" + f for f in listdir(mypath) if isfile(join(mypath, f))]
supplements.sort()
allColumns = list(pd.read_csv(
    "../stats/header_file.csv", encoding= 'unicode_escape').columns)[:-1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 tables,tables_list = get_all_paths()
#       3 mypath = "/home/datasets4/stein/supplements_jena_experiment/Y2021001bis365_csv"
# ----> 4 supplements = [mypath + "/" + f for f in listdir(mypath) if isfile(join(mypath, f))]
#       5 supplements.sort()
#       6 allColumns = list(pd.read_csv(
#       7     "../stats/header_file.csv", encoding= 'unicode_escape').columns)[:-1]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/datasets4/stein/supplements_jena_experiment/Y2021001bis365_csv'

# %%
# Test faulty column names: 
group = []
for table in tables: 
    stack = []
    for x in table: 
            try: 
                # load 
                new  = pd.read_csv(x, encoding= 'unicode_escape')
                stack.append(new["t[s]"].values[0])
            except: 
                print(x)
    stack = pd.to_datetime(stack, dayfirst=True).dayofyear
    group.append(stack)
# Out:
# /home/datasets4/stein/jena_experiment/raw/2004/Y2004D201bis250/BD20042041200.csv
# /home/datasets4/stein/jena_experiment/raw/2004/Y2004D201bis250/BD20042041408.csv
# /home/datasets4/stein/jena_experiment/raw/2004/Y2004D301bis365/BD20043521200.csv

# %%
from matplotlib.pyplot import figure
counter = 0
figure(figsize=(30, 6), dpi=80)
for x in group:
    figure(figsize=(30, 6), dpi=80)
    plt.plot(x)
    plt.title(str(2003+counter))
    plt.xlabel("day of the year")
    plt.xlabel("table NR (all tables ordered after name)")

    counter += 1
