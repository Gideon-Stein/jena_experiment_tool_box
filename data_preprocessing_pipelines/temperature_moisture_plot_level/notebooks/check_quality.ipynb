# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
### You can display some specific sections of the data here to visually inspect

# %%
# Choose your path here.
ds1 = pd.read_csv("/home/datasets4/stein/jena_experiment_data_various_products/sum_years/complete/complete_2023.csv")
ds2 = pd.read_csv("/home/datasets4/stein/jena_experiment_data_various_products/sum_years/block2/block2_2023.csv")

# %%
ds1.columns
# Out:
# Index(['datetime', 'plotcode', 'soil_temp_05cm_depth', 'soil_temp_15cm_depth'], dtype='object')

# %%
for x in ds2["plotcode"].unique():
    plt.plot(ds2.loc[ds2["plotcode"] == x,"surface_temp_south_west"].values)

# %%
for x in ds1["plotcode"].unique():
    plt.plot(ds1.loc[ds1["plotcode"] == x,"soil_temp_15cm_depth"].values)
